# %% [markdown]
# # Basic Time Series Models - Lab

# %% [markdown]
# ## Introduction
#
# Now that you have an initial understanding of the the White Noise and the Random Walk model, let's try to generate some examples!

# %% [markdown]
# ## Objectives
#
# You will be able to:
# - Explain what the goal is of time series modeling
# - Understand and explain what a White Noise model is
# - Understand and explain what a Random Walk model is
# - Understand the mathematical formulations of Random Walk and White Noise models

# %% [markdown]
# ## A White Noise Model

# %% [markdown]
# To get a good sense of how a model works, it is always a good idea to generate a process. Let's consider the following example:
# - Every day in August, September and October 2018, Nina takes the subway to work. Let's ignore weekends for now and assume that Nina works every day.
# - We know that on average, it takes her 25 minutes, and the standard deviation is 4 minutes.
# - Create and visualize a time series that reflects this information.

# %% [markdown]
# Let's import pandas, numpy and matplotlib.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


np.random.seed(12) # do not change this seed.

# %% [markdown]
# Create the dates. You can do this using `pd.date_range`, more info [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html).

# %%
# your code here
dates = pd.date_range('2018-08-01', '2018-10-31')
dates[:5]
# Out:
# DatetimeIndex(['2018-08-01', '2018-08-02', '2018-08-03', '2018-08-04',
#                '2018-08-05'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Generate the values for the white noise process representing Nina's commute in August and September.

# %%
# your code here
commute_times = np.random.normal(loc=25, scale=4, size=len(dates))
commute_times[:5]
# Out:
# array([26.89194333, 22.27429648, 25.96975799, 18.19705746, 28.01257134])

# %% [markdown]
# Create a time series with the dates and the commute times.

# %%
# your code here
ts = pd.concat([pd.Series(dates), pd.Series(commute_times)], axis=1)
ts.columns = ['date', 'time']
ts.date = pd.to_datetime(ts.date)
ts.set_index('date', inplace=True)
print(ts.info())
print(ts.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92 entries, 2018-08-01 to 2018-10-31
# Data columns (total 1 columns):
# time    92 non-null float64
# dtypes: float64(1)
# memory usage: 1.4 KB
# None
#                  time
# date
# 2018-08-01  26.891943
# 2018-08-02  22.274296
# 2018-08-03  25.969758
# 2018-08-04  18.197057
# 2018-08-05  28.012571

# %% [markdown]
# Visualize the time series and set appropriate axis labels.

# %%
# your code here
plt.figure(figsize=(16,6))
plt.plot(ts.index, ts)
plt.xlabel('Date')
plt.ylabel('Commute time (minutes)')
plt.title('Commute times, Aug.-Oct. 2018')
plt.xticks(rotation=45)
plt.show();
# Out:
# /Users/jennykreiger/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Print Nina's shortest and longest commute.

# %%
# your code here
print('Shortest commute:', min(ts.values))
print('Longest commute:', max(ts.values))
# Out:
# Shortest commute: [12.41033391]
# Longest commute: [36.48727758]

# %% [markdown]
# Look at the distribution of commute times.

# %%
# your code here
ts.hist()
ts.plot(kind='kde');

# %% [markdown]
# Compute the standard deviation and the mean of the commute series. The fact that the mean and standard error are constant over time is crucial!

# %%
# your code here
mean_time = np.mean(ts)
mean_time
# Out:
# time    24.437619
# dtype: float64

# %%
# your code here
std_time = np.std(ts)
std_time
# Out:
# time    4.2601
# dtype: float64

# %% [markdown]
# Now, let's look at the mean and standard error for August and October respectively.

# %%
# your code here
aug = ts['2018-08']
mean_aug = np.mean(aug)
std_aug = np.std(aug)

octo = ts['2018-10']
mean_oct = np.mean(octo)
std_oct = np.std(octo)

print('August:', mean_aug, std_aug)
print('October:', mean_oct, std_oct)
# Out:
# August: time    24.010692
# dtype: float64 time    4.648959
# dtype: float64
# October: time    24.302794
# dtype: float64 time    4.080769
# dtype: float64

# %% [markdown]
# Because you've generated this data, you know that the mean and constant will be the same over time. But comparing mean and standard deviation over time is useful practice for real data examples to check if a process is White Noise!

# %% [markdown]
# ## A Random Walk Model

# %% [markdown]
# Remember from the lecture that the Random Walk Model:

# %% [markdown]
# - Has no specified mean or variance
# - Has a strong dependence over time
#
# Mathematically, this can be written as:
#
# $$Y_t = Y_{t-1} + \epsilon_t$$
#
# Because today's value depends on yesterday's, you need a starting value when you start off your time series. In practice, this is what the first few time series values look like:
# $$ Y_0 = \text{some specified starting value}$$
# $$Y_1= Y_{0}+ \epsilon_1 $$
# $$Y_2= Y_{1}+ \epsilon_2 = Y_{0} + \epsilon_1 + \epsilon_2  $$
# $$Y_3= Y_{2}+ \epsilon_3 = Y_{0} + \epsilon_1 + \epsilon_2 + \epsilon_3 $$
# $$\ldots $$
#
# Keeping this in mind, let's create a random walk model:
# - starting from a value of 1000 USD of a share value upon a company's first IPO (initial public offering) in 2010 until end of November of the same year, generate a random walk model with a white noise error term, which has a standard error of 10.

# %%
# keep the random seed
np.random.seed(11)

# create a series with the specified dates
dates = pd.date_range('2010-01-01', '2010-11-30')
noise_values = np.random.normal(loc=0, scale=10, size=len(dates))
start_value = 1000
values = []
for date, noise in list(zip(dates, noise_values)):
    values.append(start_value + noise) 
    start_value = start_value + noise
    
dataset = pd.concat([pd.Series(dates), pd.Series(values)], axis=1)
dataset.columns = ['date', 'value']
dataset.date = pd.to_datetime(dataset.date)
dataset.set_index('date', inplace=True)
print(dataset.info())
print(dataset.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 334 entries, 2010-01-01 to 2010-11-30
# Data columns (total 1 columns):
# value    334 non-null float64
# dtypes: float64(1)
# memory usage: 5.2 KB
# None
#                   value
# date
# 2010-01-01  1017.494547
# 2010-01-02  1014.633817
# 2010-01-03  1009.788166
# 2010-01-04   983.254981
# 2010-01-05   983.172134

# %% [markdown]
# Visualize the time series with correct axis labels

# %%
# your code here
plt.figure(figsize=(16,6))
plt.plot(dataset.index, dataset)
plt.xlabel('Date')
plt.ylabel('Stock price ($)')
plt.title('Stock price, Jan. 1, 2010, to Nov. 30, 2010')
plt.show();

# %% [markdown]
# You can see how this very much looks like the exchange rate series you looked at in the lecture!

# %% [markdown]
# ## Random Walk with a Drift
#
# Repeat the above, but include a drift parameter $c$ of 8 now!

# %%
# keep the random seed
np.random.seed(11)

# create a series with the specified dates
dates = pd.date_range('2010-01-01', '2010-11-30')
noise_values = np.random.normal(loc=0, scale=10, size=len(dates))
start_value = 1000
values = []
for date, noise in list(zip(dates, noise_values)):
    values.append(8 + start_value + noise) 
    start_value = 8 + start_value + noise
    
dataset2 = pd.concat([pd.Series(dates), pd.Series(values)], axis=1)
dataset2.columns = ['date', 'value']
dataset2.date = pd.to_datetime(dataset2.date)
dataset2.set_index('date', inplace=True)
print(dataset2.info())
print(dataset2.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 334 entries, 2010-01-01 to 2010-11-30
# Data columns (total 1 columns):
# value    334 non-null float64
# dtypes: float64(1)
# memory usage: 5.2 KB
# None
#                   value
# date
# 2010-01-01  1025.494547
# 2010-01-02  1030.633817
# 2010-01-03  1033.788166
# 2010-01-04  1015.254981
# 2010-01-05  1023.172134

# %%
# your code here
plt.figure(figsize=(16,6))
plt.plot(dataset2.index, dataset)
plt.xlabel('Date')
plt.ylabel('Stock price ($)')
plt.title('Stock price, Jan. 1, 2010, to Nov. 30, 2010')
plt.show();

# %% [markdown]
# Note that there is a very strong drift here!

# %% [markdown]
# ## Differencing in a Random Walk model

# %% [markdown]
# One important property of the Random Walk model is that a differenced random walk returns a white noise. This is a result of the mathematical formula:
#
# $$Y_t = Y_{t-1} + \epsilon_t$$
# which is equivalent to
# $$Y_t - Y_{t-1} = \epsilon_t$$
#
# and we know that $\epsilon_t$ is a mean-zero white noise process!

# %% [markdown]
# Plot the differenced time series for the shares time series (no drift).

# %%
# your code here
dataset_diff = dataset.diff()
plt.figure(figsize=(16,6))
plt.plot(dataset_diff.index, dataset_diff)
plt.xlabel('Date')
plt.ylabel('Differenced stock price ($)')
plt.title('Differenced stock price, Jan. 1, 2010, to Nov. 30, 2010')
plt.show();

# %% [markdown]
# This does look a lot like a white noise series!

# %% [markdown]
# Plot the differenced time series for the shares time series (with a drift).

# %%
# your code here
dataset2_diff = dataset2.diff()
plt.figure(figsize=(16,6))
plt.plot(dataset2_diff.index, dataset2_diff)
plt.xlabel('Date')
plt.ylabel('Differenced stock price ($)')
plt.title('Differenced stock price, Jan. 1, 2010, to Nov. 30, 2010')
plt.show();

# %% [markdown]
# This is also a white noise series, but what can you tell about the mean?

# %% [markdown]
# The mean is equal to the drift $c$, so 8 for this example!

# %% [markdown]
# ## Summary
#
# Great, you now know how a Random Walk and Moving Average model work!
