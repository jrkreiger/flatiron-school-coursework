# %% [markdown]
# # Modeling Your Data - Lab
#
# ## Introduction
#
# In this lab you'll perform a full linear regression on the data. You'll implement the process demonstrated in the previous lesson, taking a stepwise approach to analyze and improve the model along the way.
#
# ## Objectives
# You will be able to:
#
# * Remove predictors with p-values too high and refit the model
# * Examine and interpret the model results
# * Split data into training and test sets
# * Fit a regression model to the dataset using the `statsmodels` library
#
#
# ## Build an Initial Regression Model
#
# To start, perform a train-test split and create an initial regression model to model the `list_price` using all of your available features.
#
# > **Note:** In order to write the model you'll have to do some tedious manipulation of your column names. Statsmodels will not allow you to have spaces, apostrophe or arithmetic symbols (+) in your column names. Preview them and refine them as you go.
# **If you receive an error such as "PatsyError: error tokenizing input (maybe an unclosed string?)", then you need to further preprocess your column names.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')

from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.model_selection import train_test_split

# %%
# Import the dataset 'Lego_dataset_cleaned.csv'
df = pd.read_csv('Lego_dataset_cleaned.csv')
df.head()
# Out:
#    piece_count  list_price  num_reviews  play_star_rating  star_rating  \
# 0    -0.273020       29.99    -0.398512         -0.655279    -0.045687
# 1    -0.404154       19.99    -0.398512         -0.655279     0.990651
# 2    -0.517242       12.99    -0.147162         -0.132473    -0.460222
# 3     0.635296       99.99     0.187972         -1.352353     0.161581
# 4     0.288812       79.99    -0.063378         -2.049427     0.161581
#
#    val_star_rating  ages_10+  ages_10-14  ages_10-16  ages_10-21  ...  \
# 0        -0.365010         0           0           0           0  ...
# 1        -0.365010         0           0           0           0  ...
# 2        -0.204063         0           0           0           0  ...
# 3         0.117830         0           0           0           0  ...
# 4        -0.204063         0           0           0           0  ...
#
#    country_NZ  country_PL  country_PT  country_US  review_difficulty_Average  \
# ...

# %%
# Your code here - Manipulate column names
list(df.columns)
# Out:
# ['piece_count',
#  'list_price',
#  'num_reviews',
#  'play_star_rating',
#  'star_rating',
#  'val_star_rating',
#  'ages_10+',
#  'ages_10-14',
#  'ages_10-16',
#  'ages_10-21',
#  'ages_11-16',
#  'ages_12+',
#  'ages_12-16',
#  'ages_14+',
#  'ages_16+',
#  'ages_1½-3',
#  'ages_1½-5',
#  'ages_2-5',
#  'ages_4+',
#  'ages_4-7',
#  'ages_4-99',
#  'ages_5+',
#  'ages_5-12',
#  'ages_5-8',
#  'ages_6+',
#  'ages_6-12',
#  'ages_6-14',
#  'ages_7+',
#  'ages_7-12',
#  'ages_7-14',
#  'ages_8+',
#  'ages_8-12',
#  'ages_8-14',
#  'ages_9+',
#  'ages_9-12',
#  'ages_9-14',
#  'ages_9-16',
#  'theme_name_Angry Birds™',
#  'theme_name_Architecture',
#  'theme_name_BOOST',
#  "theme_name_Blue's Helicopter Pursuit",
#  'theme_name_BrickHeadz',
#  'theme_name_Carnotaurus Gyrosphere Escape',
#  'theme_name_City',
#  'theme_name_Classic',
#  'theme_name_Creator 3-in-1',
#  'theme_name_Creator Expert',
#  'theme_name_DC Comics™ Super Heroes',
#  'theme_name_DC Super Hero Girls',
# ...

# %%
cols_to_clean = ['ages_10+', 'ages_12+', 'ages_14+', 'ages_16+', 'ages_4+',
                 'ages_5+', 'ages_6+', 'ages_7+', 'ages_8+', 'ages_9+']
cols_clean = [x.replace('+', '_and_up') for x in cols_to_clean]
cols_dict = dict(zip(cols_to_clean, cols_clean))
cols_dict['ages_1½-3'] = 'ages_1_and_a_half_3'
cols_dict['ages_1½-5'] = 'ages_1_and_a_half_5'
df.rename(columns=cols_dict, inplace=True)
list(df.columns)
# Out:
# ['piece_count',
#  'list_price',
#  'num_reviews',
#  'play_star_rating',
#  'star_rating',
#  'val_star_rating',
#  'ages_10_and_up',
#  'ages_10-14',
#  'ages_10-16',
#  'ages_10-21',
#  'ages_11-16',
#  'ages_12_and_up',
#  'ages_12-16',
#  'ages_14_and_up',
#  'ages_16_and_up',
#  'ages_1_and_a_half_3',
#  'ages_1_and_a_half_5',
#  'ages_2-5',
#  'ages_4_and_up',
#  'ages_4-7',
#  'ages_4-99',
#  'ages_5_and_up',
#  'ages_5-12',
#  'ages_5-8',
#  'ages_6_and_up',
#  'ages_6-12',
#  'ages_6-14',
#  'ages_7_and_up',
#  'ages_7-12',
#  'ages_7-14',
#  'ages_8_and_up',
#  'ages_8-12',
#  'ages_8-14',
#  'ages_9_and_up',
#  'ages_9-12',
#  'ages_9-14',
#  'ages_9-16',
#  'theme_name_Angry Birds™',
#  'theme_name_Architecture',
#  'theme_name_BOOST',
#  "theme_name_Blue's Helicopter Pursuit",
#  'theme_name_BrickHeadz',
#  'theme_name_Carnotaurus Gyrosphere Escape',
#  'theme_name_City',
#  'theme_name_Classic',
#  'theme_name_Creator 3-in-1',
#  'theme_name_Creator Expert',
# ...

# %%
cols_list = list(df.columns)
cols_list = [col.replace(' ', '_') for col in cols_list]
cols_list = [col.replace('™', '') for col in cols_list]
cols_list = [col.replace('®', '') for col in cols_list]
cols_list = [col.replace('.', '') for col in cols_list]
cols_list = [col.replace('-', '_') for col in cols_list]
cols_list = [col.replace('\'', '') for col in cols_list]

df.columns = cols_list
list(df.columns)
# Out:
# ['piece_count',
#  'list_price',
#  'num_reviews',
#  'play_star_rating',
#  'star_rating',
#  'val_star_rating',
#  'ages_10_and_up',
#  'ages_10_14',
#  'ages_10_16',
#  'ages_10_21',
#  'ages_11_16',
#  'ages_12_and_up',
#  'ages_12_16',
#  'ages_14_and_up',
#  'ages_16_and_up',
#  'ages_1_and_a_half_3',
#  'ages_1_and_a_half_5',
#  'ages_2_5',
#  'ages_4_and_up',
#  'ages_4_7',
#  'ages_4_99',
#  'ages_5_and_up',
#  'ages_5_12',
#  'ages_5_8',
#  'ages_6_and_up',
#  'ages_6_12',
#  'ages_6_14',
#  'ages_7_and_up',
#  'ages_7_12',
#  'ages_7_14',
#  'ages_8_and_up',
#  'ages_8_12',
#  'ages_8_14',
#  'ages_9_and_up',
#  'ages_9_12',
#  'ages_9_14',
#  'ages_9_16',
#  'theme_name_Angry_Birds',
#  'theme_name_Architecture',
#  'theme_name_BOOST',
#  'theme_name_Blues_Helicopter_Pursuit',
#  'theme_name_BrickHeadz',
#  'theme_name_Carnotaurus_Gyrosphere_Escape',
#  'theme_name_City',
#  'theme_name_Classic',
#  'theme_name_Creator_3_in_1',
#  'theme_name_Creator_Expert',
# ...

# %%
df.head()
# Out:
#    piece_count  list_price  num_reviews  play_star_rating  star_rating  \
# 0    -0.273020       29.99    -0.398512         -0.655279    -0.045687
# 1    -0.404154       19.99    -0.398512         -0.655279     0.990651
# 2    -0.517242       12.99    -0.147162         -0.132473    -0.460222
# 3     0.635296       99.99     0.187972         -1.352353     0.161581
# 4     0.288812       79.99    -0.063378         -2.049427     0.161581
#
#    val_star_rating  ages_10_and_up  ages_10_14  ages_10_16  ages_10_21  ...  \
# 0        -0.365010               0           0           0           0  ...
# 1        -0.365010               0           0           0           0  ...
# 2        -0.204063               0           0           0           0  ...
# 3         0.117830               0           0           0           0  ...
# 4        -0.204063               0           0           0           0  ...
#
#    country_NZ  country_PL  country_PT  country_US  review_difficulty_Average  \
# ...

# %%
# Your code here - Define the target and predictors
target = 'list_price'
features_list = list(df.drop('list_price', axis=1).columns)
features = '+'.join(features_list)
formula = target + '~' + features

# %%
# Your code here - Split into train and test
train, test = train_test_split(df)

# %%
# Your code here - Fit the actual model
model = ols(formula, train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             list_price   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     555.4
# Date:                Mon, 14 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:08:06   Log-Likelihood:                -40540.
# No. Observations:                8152   AIC:                         8.127e+04
# Df Residuals:                    8057   BIC:                         8.193e+04
# Df Model:                          94
# Covariance Type:            nonrobust
# ...
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Remove the Uninfluential Features
#
# Based on the initial model, remove those features which do not appear to be statistically relevant and rerun the model.

# %% [markdown]
# ### Get p-values out of the summary table

# %%
# Extract the p-value table from the summary and use it to subset our features
summary = model.summary()
summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             list_price   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     555.4
# Date:                Mon, 14 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:08:06   Log-Likelihood:                -40540.
# No. Observations:                8152   AIC:                         8.127e+04
# Df Residuals:                    8057   BIC:                         8.193e+04
# Df Model:                          94
# Covariance Type:            nonrobust
# ...
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# ...

# %%
p_table = summary.tables[1]
p_table = pd.DataFrame(p_table.data)
p_table
# Out:
#                                       0           1          2          3  \
# 0                                              coef    std err          t
# 1                             Intercept     65.4345      1.859     35.198
# 2                           piece_count     72.1982      0.899     80.332
# 3                           num_reviews      6.1986      0.684      9.069
# 4                      play_star_rating      5.6044      0.627      8.935
# ..                                  ...         ...        ...        ...
# 99        review_difficulty_Challenging     22.4833      2.119     10.609
# 100              review_difficulty_Easy      3.3824      1.648      2.053
# 101  review_difficulty_Very_Challenging     18.2557      8.051      2.268
# 102         review_difficulty_Very_Easy      1.1498      2.024      0.568
# 103           review_difficulty_unknown      3.3688      1.813      1.858
#
#           4          5          6
# 0     P>|t|     [0.025     0.975]
# ...

# %%
p_table.columns = p_table.iloc[0]
p_table = p_table.drop(0)
p_table = p_table.set_index(p_table.columns[0])
p_table['P>|t|'] = p_table['P>|t|'].astype(float)
p_table
# Out:
# 0                                         coef    std err          t  P>|t|  \
#
# Intercept                              65.4345      1.859     35.198  0.000
# piece_count                            72.1982      0.899     80.332  0.000
# num_reviews                             6.1986      0.684      9.069  0.000
# play_star_rating                        5.6044      0.627      8.935  0.000
# star_rating                            -1.2696      0.708     -1.794  0.073
# ...                                        ...        ...        ...    ...
# review_difficulty_Challenging          22.4833      2.119     10.609  0.000
# review_difficulty_Easy                  3.3824      1.648      2.053  0.040
# review_difficulty_Very_Challenging     18.2557      8.051      2.268  0.023
# review_difficulty_Very_Easy             1.1498      2.024      0.568  0.570
# review_difficulty_unknown               3.3688      1.813      1.858  0.063
#
# ...

# %%
new_cols = list(p_table[p_table['P>|t|'] < 0.05].index)
new_cols.remove('Intercept')
print(len(p_table), len(new_cols))
print(new_cols[:5])
p_table.head()
# Out:
# 103 71
# ['piece_count', 'num_reviews', 'play_star_rating', 'val_star_rating', 'ages_10_and_up']
# 0                       coef    std err          t  P>|t|     [0.025  \
#
# Intercept            65.4345      1.859     35.198  0.000     61.790
# piece_count          72.1982      0.899     80.332  0.000     70.436
# num_reviews           6.1986      0.684      9.069  0.000      4.859
# play_star_rating      5.6044      0.627      8.935  0.000      4.375
# star_rating          -1.2696      0.708     -1.794  0.073     -2.657
#
# 0                    0.975]
#
# Intercept            69.079
# piece_count          73.960
# num_reviews           7.539
# play_star_rating      6.834
# star_rating           0.118

# %% [markdown]
# ### Redo the model

# %%
features = '+'.join(new_cols)
formula = target + '~' + features

# %%
# Your code here - Refit the model
model = ols(formula, train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             list_price   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     744.4
# Date:                Mon, 14 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:08:07   Log-Likelihood:                -40557.
# No. Observations:                8152   AIC:                         8.126e+04
# Df Residuals:                    8081   BIC:                         8.175e+04
# Df Model:                          70
# Covariance Type:            nonrobust
# ...
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# > **Comment:** You should see that the model performance is identical. Additionally, observe that there are further features which have been identified as unimpactful. Continue to refine the model accordingly.

# %%
# Your code here - Continue to refine the model
summary = model.summary()
p_table = summary.tables[1]
p_table = pd.DataFrame(p_table.data)
p_table.columns = p_table.iloc[0]
p_table = p_table.drop(0)
p_table = p_table.set_index(p_table.columns[0])
p_table['P>|t|'] = p_table['P>|t|'].astype(float)
new_cols = list(p_table[p_table['P>|t|'] < 0.05].index)
new_cols.remove('Intercept')
features = '+'.join(new_cols)
formula = target + '~' + features
model = ols(formula, train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             list_price   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     897.1
# Date:                Mon, 14 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:08:07   Log-Likelihood:                -40567.
# No. Observations:                8152   AIC:                         8.125e+04
# Df Residuals:                    8093   BIC:                         8.167e+04
# Df Model:                          58
# Covariance Type:            nonrobust
# ...
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Investigate Multicollinearity
#
# There are still a lot of features in the current model! Chances are there are some strong multicollinearity issues. Begin to investigate the extent of this problem.

# %%
# Your code here - Code a way to identify multicollinearity
def find_multicollinearity(cols, data):
    X = data[cols]
    vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    output_list = list(zip(cols, vif))
    return output_list

# %%
vif = find_multicollinearity(new_cols, train)
# Out:
# /Users/jennykreiger/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/stats/outliers_influence.py:185: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %% [markdown]
# ## Perform Another Round of Feature Selection
#
# Once again, subset your features based on your findings above. Then rerun the model once again.

# %%
# Your code here - Subset features based on multicollinearity
new_cols = [x for x,v in vif if v < 5]

# %%
features = '+'.join(new_cols)
formula = target + '~' + features
model = ols(formula, train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             list_price   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     871.2
# Date:                Mon, 14 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:08:10   Log-Likelihood:                -40987.
# No. Observations:                8152   AIC:                         8.208e+04
# Df Residuals:                    8098   BIC:                         8.246e+04
# Df Model:                          53
# Covariance Type:            nonrobust
# ...
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Check the Normality Assumption
#
# Check whether the normality assumption holds for your model.

# %%
# Your code here - Check that the residuals are normally distributed
sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True);

# %% [markdown]
# ## Check Homoscedasticity Assumption
#
# Check whether the model's errors are indeed homoscedastic or if they violate this principle and display heteroscedasticity.

# %%
# Your code here - Check that the residuals are homoscedastic
plt.scatter(model.predict(train[new_cols]), model.resid)
plt.plot(model.predict(train[new_cols]), [0 for i in range(len(train))]);

# %% [markdown]
# > **Comment:** This displays a fairly pronounced 'funnel' shape: errors appear to increase as the `list_price` increases. This doesn't bode well for our model. Subsetting the data to remove outliers and confining the model to this restricted domain may be necessary. A log transformation or something equivalent may also be appropriate.

# %% [markdown]
# ## Make Additional Refinements
#
# From here, make additional refinements to your model based on the above analysis. As you progress, continue to go back and check the assumptions for the updated model. Be sure to attempt at least two additional model refinements.

# %% [markdown]
# > **Comment:** Based on the above plots, it seems as though outliers are having a substantial impact on the model. As such, removing outliers may be appropriate. Investigating the impact of a log transformation is also worthwhile.

# %%
# Your code here - Check for outliers
df.list_price.hist()

# %%
# Identify a cutoff point
for i in range(90, 100):
    print(str(i) + 'th percentile: {}'.format(np.percentile(df.list_price, i)))
# Out:
# 90th percentile: 143.952
# 91th percentile: 153.986
# 92th percentile: 170.7878
# 93th percentile: 182.9878
# 94th percentile: 198.7929
# 95th percentile: 220.03032999999942
# 96th percentile: 251.90543999999994
# 97th percentile: 292.7878
# 98th percentile: 359.88
# 99th percentile: 463.5878

# %%
# Remove extreme outliers
df_trimmed = df[df.list_price < 450]
print('Percent removed: {}'.format((len(df) - len(df_trimmed))/len(df)))
# Out:
# Percent removed: 0.010487580496780129

# %%
# Log-transform list_price
df.list_price = df.list_price.map(np.log)

# %%
# Split the data
train, test = train_test_split(df)

# %%
# Rerun the model
predictors = '+'.join(new_cols)
formula = target + "~" + predictors
model = ols(formula=formula, data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             list_price   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Mon, 14 Oct 2019   Prob (F-statistic):               0.00
# Time:                        13:12:21   Log-Likelihood:                -5343.8
# No. Observations:                8152   AIC:                         1.080e+04
# Df Residuals:                    8098   BIC:                         1.117e+04
# Df Model:                          53
# Covariance Type:            nonrobust
# ...
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Your code here - Check normality assumption
sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True);

# %%
# Your code here - Check the Homoscedasticity Assumption
plt.scatter(model.predict(train[new_cols]), model.resid)
plt.plot(model.predict(train[new_cols]), [0 for i in range(len(train))]);

# %%
# Handpick features and rerun the model
pick_cols = ['piece_count', 'theme_name_SERIOUS_PLAY', 'country_US', 
             'ages_6_and_up', 'review_difficulty_Challenging']

# %%
# Rerun the model (using training data with outliers removed & log-transformed)
predictors = '+'.join(pick_cols)
formula = target + "~" + predictors
model = ols(formula=formula, data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             list_price   R-squared:                       0.537
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     1887.
# Date:                Mon, 14 Oct 2019   Prob (F-statistic):               0.00
# Time:                        13:18:18   Log-Likelihood:                -7963.4
# No. Observations:                8152   AIC:                         1.594e+04
# Df Residuals:                    8146   BIC:                         1.598e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
# Check for normality
sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True);

# %%
# Check the Homoscedasticity Assumption
plt.scatter(model.predict(train[new_cols]), model.resid)
plt.plot(model.predict(train[new_cols]), [0 for i in range(len(train))]);

# %% [markdown]
# The heteroscedasticity hasn't really improved, but my chosen features were enough to score an adjusted R<sup>2</sup> of 0.536.

# %% [markdown]
# ## Summary

# %% [markdown]
# Well done! As you can see, regression can be a challenging task that requires you to make decisions along the way, try alternative approaches and make ongoing refinements. These choices depend on the context and specific use cases.
