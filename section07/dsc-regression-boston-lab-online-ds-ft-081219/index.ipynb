# %% [markdown]
# # Project: Regression Modeling with the Boston Housing Dataset
#
# ## Introduction
#
# In this final lab, you'll apply the regression analysis and diagnostics techniques covered in this section to the famous "Boston Housing" dataset. You performed a detailed EDA for this dataset earlier on, and hopefully, you more or less recall how this data is structured! In this lab, you'll use some of the features in this dataset to create a linear model to predict the house price!
#
# ## Objectives
# You will be able to:
# * Build many linear models with the Boston housing data using OLS
# * Analyze OLS diagnostics for model validity
# * Visually explain the results and interpret the diagnostics from Statsmodels
# * Comment on the goodness of fit for a simple regression model
#
# ## Let's get started
#
# ### Import necessary libraries and load 'BostonHousing.csv' as a pandas dataframe

# %%
# Import necessary libraries and load data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import statsmodels.stats.api as sms
import seaborn as sns

# %matplotlib inline

data = pd.read_csv('BostonHousing.csv')

# %% [markdown]
# The columns in the Boston housing data represent the dependent and independent variables. The dependent variable here is the median house value `MEDV`. The description of the other variables is available on [KAGGLE](https://www.kaggle.com/c/boston-housing).
#
# ### Inspect the columns of the dataset and comment on type of variables present

# %%
# Inspect the first few rows of data
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# The dataset contains columns recording crime rates, zoning types, location near the river or not, nitrogen oxide concentration (an indicator of air quality), average number of rooms per house, average age of house, weighted distance from major employment centers, an index of how close houses are to radial highways, tax rate, pupil-teacher ratio in schools, a ratio reflecting the size of the Black population, another population measure, and the median home value. Rows in the dataset represent towns in the Boston suburbs.

# %% [markdown]
# ### Create histograms for all variables in the dataset and comment on their shape (uniform or not?)

# %%
# Plot a histogram for each variable
cols = list(data.columns)

plt.figure(figsize=(16, 12))

for index, column in enumerate(cols):
    ax = plt.subplot(4, 4, index+1)
    data[column].plot.hist(ax=ax)
    ax.set_title(column)

plt.show();

# %% [markdown]
# A few observations:
# - crim (Crime rate) looks like it may be skewed by an outlier at the far right.
# - chas is clearly a binary variable (properties are either on the river or not).
# - rm (average number of rooms) looks like a pretty normal distribution.
# - age (percentage of homes in a town built before 1940) skews left because there are many neighborhoods where most of the houses are older than 1940.
# - dis is right-skewed, meaning that most towns have a low weighted distance to major employment centers.
# - rad (index of connectedness to radial highways) shows an interesting split between low values and very high ones.
# - Likewise for tax rate; most values fall in a certain range, but then a large number of values fall in a narrow high range.
# - There appears to be a pupil-teacher ratio around 21 that is very common.
# - That high spike in 'b' (ratio of Black to non-Black residents) reflects a large number of communities with 0% Black inhabitants.
# - The documentation is not clear on what 'lstat' means.
# - medv (median home value) would be normally distributed if not for a group of values at the high end, representing a group of towns where median home value is in the \$450k-500k range.

# %% [markdown]
# Based on this, we preselected some features  for you which appear to be more 'normal' than others.
# ### Create a new dataset with `['crim', 'dis', 'rm', 'zn', 'age', 'medv']`

# %%
# Your code here
data_narrow = data.loc[:,['crim', 'dis', 'rm', 'zn', 'age', 'medv']]
data_narrow.head()
# Out:
#       crim     dis     rm    zn   age  medv
# 0  0.00632  4.0900  6.575  18.0  65.2  24.0
# 1  0.02731  4.9671  6.421   0.0  78.9  21.6
# 2  0.02729  4.9671  7.185   0.0  61.1  34.7
# 3  0.03237  6.0622  6.998   0.0  45.8  33.4
# 4  0.06905  6.0622  7.147   0.0  54.2  36.2

# %% [markdown]
# ### Check for linearity assumption for all chosen features with target variable using scatter plots

# %%
for column in data_narrow:
    data_narrow.plot(kind='scatter', x = column, y = 'medv', label=column)
    plt.legend()
    plt.show();

# %% [markdown]
# All the plots look more or less linear, but with the potential for heterscedasticity. 'zn' appears to be a categorical variable.

# %% [markdown]
# Clearly, your data needs a lot of preprocessing to improve the results. This key behind a Kaggle competition is to process the data in such a way that you can identify the relationships and make predictions in the best possible way. For now, we'll leave the dataset untouched and just move on with the regression. The assumptions are not _exactly_ all fulfilled, but they still hold to a level that we can move on.
#
# ### Let's do Regression
#
# Now, let's perform a number of simple regression experiments between the chosen independent variables and the dependent variable (price). You'll do this in a loop and in every iteration, you should pick one of the independent variables. Perform the following steps:
#
# * Run a simple OLS regression between independent and dependent variables
# * Plot a regression line on the scatter plots
# * Plot the residuals using `sm.graphics.plot_regress_exog()`
# * Plot a Q-Q plot for regression residuals normality test
# * Store following values in array for each iteration:
#     * Independent Variable
#     * r_squared'
#     * intercept'
#     * 'slope'
#     * 'p-value'
#     * 'normality (JB)'
# * Comment on each output

# %%
# Run the analysis

indep_vars = ['crim', 'dis', 'rm', 'zn', 'age']
results = [['indep_variable', 'r_squared', 'intercept', 'slope', 'p_value', 'normality (JB)']]
for var in indep_vars:
    formula = str('medv~' + var)
    model = smf.ols(formula=formula, data=data_narrow).fit()
    var_minmax = pd.DataFrame({var: [data_narrow[var].min(), data_narrow[var].max()]})
    predicted = model.predict(var_minmax)
    print('Boston Housing DataSet - Regression Analysis and Diagnostics for formula: {}'.format(formula))
    print('-------------------------------------------------------------------------------------')
    plt.scatter(x=var, y='medv', data=data_narrow, label='Data')
    plt.plot(var_minmax, predicted, color='red', label='Prediction Line')
    plt.title('medv ~ ' + var)
    plt.plot()
    fig = plt.figure(figsize=(16,8))
    fig = sm.graphics.plot_regress_exog(model, var, fig=fig)
    plt.show()
    fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)
    plt.show()
    results.append([var, model.rsquared, model.params[0], model.params[1], 
                   model.pvalues[1], sms.jarque_bera(model.resid)[0]])
    input('Press Enter to continue.')
# Out:
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~crim
# -------------------------------------------------------------------------------------
# Press Enter to continue.
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~dis
# -------------------------------------------------------------------------------------
# Press Enter to continue.
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~rm
# -------------------------------------------------------------------------------------
# Press Enter to continue.
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~zn
# -------------------------------------------------------------------------------------
# Press Enter to continue.
# Boston Housing DataSet - Regression Analysis and Diagnostics for formula: medv~age
# -------------------------------------------------------------------------------------
# Press Enter to continue.

# %%
pd.DataFrame(results)
# Out:
#                 0          1          2         3            4               5
# 0  indep_variable  r_squared  intercept     slope      p_value  normality (JB)
# 1            crim    0.15078    24.0331  -0.41519  1.17399e-19         295.404
# 2             dis  0.0624644    18.3901   1.09161  1.20661e-08         305.104
# 3              rm   0.483525   -34.6706   9.10211  2.48723e-74         612.449
# 4              zn   0.129921    20.9176   0.14214  5.71358e-17         262.387
# 5             age   0.142095    30.9787 -0.123163  1.56998e-18         456.983

# %% [markdown]
# Of the five variables studied, 'rm' (mean number of rooms) is the best predictor of median home value for a town. In our model, 'rm' predicts 48% of the variation in 'medv'. I have concerns about whether any of the independent variables is normally distributed; both the Q-Q plots and the JB values seem to indicate that otherwise.

# %% [markdown]
# Clearly, the results are not very reliable. The best R-Squared is witnessed with `rm`, so in this analysis, this is our best predictor.
#
# ### How can you improve these results?
# 1. Preprocessing
#
# This is where preprocessing of data comes in. Dealing with outliers, normalizing data, scaling values etc. can help regression analysis get more meaningful results from the given data.
#
# 2. Advanced Analytical Methods
#
# Simple regression is a very basic analysis technique and trying to fit a straight line solution to complex analytical questions may prove to be very inefficient. Later on, you'll explore at multiple regression where you can use multiple features **at once** to define a relationship with the outcome. You'll also look at some preprocessing and data simplification techniques and revisit the Boston dataset with an improved toolkit.
#
# ## Level up - Optional
#
# Apply some data wrangling skills that you have learned in the previous section to pre-process the set of independent variables we chose above. You can start off with outliers and think of a way to deal with them. See how it affects the goodness of fit.
#
# ## Summary
#
# In this lab, you applied your skills learned so far on a new data set. You looked at the outcome of your analysis and realized that the data might need some preprocessing to see a clear improvement in results. You'll pick this back up later on, after learning about more preprocessing techniques and advanced modeling techniques.
