# %% [markdown]
# # Recommendation Systems - Lab
#
# ## Introduction
#
# Now that you've gotten an introduction to collaborative filtering and recommendation systems, it's time to put your skills to test and attempt to build a recommendation system for a real world dataset! For this exercise, you'll be using a dataset regarding the book reviews on the Amazon marketplace. While the previous lesson focused on user-based recommendation systems, you'll apply a parallel process for an item-based recommendation system to recommend similar books at the bottom of the product page.
#
# ## Objectives
#
# You will be able to:
# * Implement a recommendation system on a real world dataset

# %% [markdown]
# ## Load the Dataset

# %%
#Your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import networkx as nx
import warnings
warnings.filterwarnings('ignore')

# %%
books = pd.read_csv('books_data.edgelist', 
                    names=['source', 'target', 'weight'], 
                    delimiter=' ')
books.head()
# Out:
#        source      target  weight
# 0  0827229534  0804215715     0.7
# 1  0827229534  156101074X     0.5
# 2  0827229534  0687023955     0.8
# 3  0827229534  0687074231     0.8
# 4  0827229534  082721619X     0.7

# %% [markdown]
# ## Load the MetaData

# %%
#Your code here
books_meta = pd.read_csv('books_meta.txt', delimiter='\t')
books_meta.head()
# Out:
#    Id        ASIN                                              Title  \
# 0   1  0827229534            Patterns of Preaching: A Sermon Sampler
# 1   2  0738700797                         Candlemas: Feast of Flames
# 2   3  0486287785   World War II Allied Fighter Planes Trading Cards
# 3   4  0842328327  Life Application Bible Commentary: 1 and 2 Tim...
# 4   5  1577943082    Prayers That Avail Much for Business: Executive
#
#                                           Categories Group  SalesRank  \
# 0  clergi sermon subject religion preach spiritu ...  Book     396585
# 1  subject witchcraft earth religion spiritu base...  Book     168596
# 2       general hobbi subject craft home garden book  Book    1270652
# 3  spiritu translat commentari christian book gui...  Book     631289
# 4  subject religion spiritu busi christian live w...  Book     455160
#
#    TotalReviews  AvgRating  DegreeCentrality  ClusteringCoeff
# 0             2        5.0                 8             0.80
# 1            12        4.5                 9             0.85
# 2             1        5.0                 0             0.00
# 3             1        4.0                 6             0.79
# 4             0        0.0                 4             1.00

# %% [markdown]
# ## Select Books to Test Your Recommender On
#
# Select a small subset of books that you are interested in generating recommendations for.

# %%
pompeii = books_meta[books_meta.Title.str.contains('Pompeii')]
len(pompeii)
# Out:
# 22

# %% [markdown]
# ## Generate Recommendations for a Few Books of Choice
#
# The 'books_data.edgelist' has conveniently already calculated the distance between items for you. Given this preprocessed and data, it's time to employ collaborative filtering to generate recommendations! Generate the top 10 recommendations for each book in the subset you chose. Be sure to print the book name that you are generating recommendations for as well as the name of the books being recommended.

# %%
rec_dict = {}
id_name_dict = dict(zip(books_meta.ASIN, books_meta.Title))

for row in pompeii.index:
    book_id = pompeii.ASIN[row]
    book_name = id_name_dict[book_id]
    most_similar = books[(books.source == book_id)
                         | (books.target == book_id)
                        ].sort_values(by='weight', ascending=False).head(10)
    most_similar['source_name'] = most_similar['source'].map(id_name_dict)
    most_similar['target_name'] = most_similar['target'].map(id_name_dict)
    recs = []
    for row in most_similar.index:
        if most_similar.source[row] == 'book_id':
            recs.append((most_similar.target_name[row], most_similar.weight[row]))
        else:
            recs.append((most_similar.source_name[row], most_similar.weight[row]))
    rec_dict[book_name] = recs
    print('Recommended for:', book_name)
    for rec in recs:
        print(rec)
    print('\n')
# Out:
# Recommended for: Michelin In Your Pocket Naples, Pompeii, Capri, Sorrento, and the Amalfi Coast, 1e (In Your Pocket)
# ('Michelin In Your Pocket Naples, Pompeii, Capri, Sorrento, and the Amalfi Coast, 1e (In Your Pocket)', 0.79)
# ('Michelin In Your Pocket Naples, Pompeii, Capri, Sorrento, and the Amalfi Coast, 1e (In Your Pocket)', 0.79)
# ('Michelin In Your Pocket Naples, Pompeii, Capri, Sorrento, and the Amalfi Coast, 1e (In Your Pocket)', 0.73)
# ('Michelin In Your Pocket Naples, Pompeii, Capri, Sorrento, and the Amalfi Coast, 1e (In Your Pocket)', 0.69)
# ('Michelin In Your Pocket Naples, Pompeii, Capri, Sorrento, and the Amalfi Coast, 1e (In Your Pocket)', 0.65)
#
#
# Recommended for: Last Days of Pompeii
# ('Last Days of Pompeii', 0.11)
# ('Last Days of Pompeii', 0.11)
# ('Rome: An Oxford Archaeological Guide (Oxford Archaeological Guides)', 0.07)
#
#
# Recommended for: In Search of Pompeii : A buried Roman city
# ('In Search of Pompeii : A buried Roman city', 0.92)
# ('Pompeii (Roman World)', 0.73)
# ('In Search of Pompeii : A buried Roman city', 0.33)
# ('In Search of Pompeii : A buried Roman city', 0.33)
# ('In Search of Pompeii : A buried Roman city', 0.3)
# ('In Search of Pompeii : A buried Roman city', 0.18)
#
#
# Recommended for: Houses and Society in Pompeii and Herculaneum
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.5)
# ('The Lost World of Pompeii', 0.5)
# ('Houses and Society in Pompeii and Herculaneum', 0.44)
# ('Houses and Society in Pompeii and Herculaneum', 0.41)
# ('Roman Pompeii: Space and Society', 0.38)
# ('Houses and Society in Pompeii and Herculaneum', 0.24)
#
#
# Recommended for: Pompeii : An Architectural History
# ('Houses and Society in Pompeii and Herculaneum', 0.44)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.18)
# ('Roman Pompeii: Space and Society', 0.17)
#
#
# Recommended for: Women and Beauty in Pompeii
#
#
# Recommended for: Pompeii: Monuments Past and Present (Monuments Past and Present)
# ('Pompeii', 1.0)
# ('Ancient Rome: Monuments Past and Present (Monuments Past and Present)', 1.0)
# ('Ancient Greece: The Famous Monuments Past and Present (Monuments Past and Present)', 0.92)
#
#
# Recommended for: Cities of Vesuvius: Pompeii & Herculaneum
# ('Roman Pompeii: Space and Society', 0.44)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.38)
# ('Houses and Society in Pompeii and Herculaneum', 0.24)
#
#
# Recommended for: Pompeii: Public and Private Life (Revealing Antiquity)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 1.0)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.6)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.5)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.44)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.38)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.28)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.18)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.18)
# ('Last Days of Pompeii', 0.11)
#
#
# Recommended for: Eroticism in Pompeii
# ('Eroticism in Pompeii', 0.55)
# ('Sacred Sexuality in Ancient Egypt: The Erotic Secrets of the Forbidden Papyri', 0.15)
#
#
# Recommended for: The Buried City of Pompeii : Picturebook
# ('The Buried City of Pompeii : Picturebook', 0.62)
# ('Pompeii (Roman World)', 0.44)
# ('In Search of Pompeii : A buried Roman city', 0.33)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 0.3)
# ('In Search of a Homeland : The Story of the Aeneid', 0.23)
#
#
# Recommended for: Pompeii
# ('Pompeii', 1.0)
# ('The Houses of Roman Italy 100 B.C.-A.D. 250: Ritual, Space, and Decoration', 0.41)
# ('The Lost World of Pompeii', 0.34)
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.18)
#
#
# Recommended for: Pompeii (Roman World)
# ('The Roman Fort (The Roman World)', 1.0)
# ('The Legionary (The Roman World Series)', 0.89)
# ('The Cavalryman (The Roman World Series)', 0.89)
# ('Pompeii (Roman World)', 0.73)
# ('Pompeii (Roman World)', 0.44)
# ('Pompeii (Roman World)', 0.27)
# ('Pompeii (Roman World)', 0.23)
# ('Pompeii (Roman World)', 0.21)
#
#
# Recommended for: The Villa of the Mysteries of Pompeii: Ancient Ritual, Modern Muse
#
#
# Recommended for: Pompeii...Buried Alive! (Step-Into-Reading, Step 4)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 1.0)
# ('Volcanoes! Mountains of Fire (Step-Into-Reading, Step 4)', 0.62)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 0.62)
# ('True-Life Treasure Hunts (Step-Into-Reading, Step 5)', 0.62)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 0.62)
# ('Quakes! (Step-Into-Reading, Step 5)', 0.62)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 0.57)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 0.57)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 0.57)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 0.53)
#
#
# Recommended for: The Lost World of Pompeii
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.6)
# ('Pompeii: The Day a City Died', 0.56)
# ('The Lost World of Pompeii', 0.5)
# ('The Lost World of Pompeii', 0.34)
# ('In Search of Pompeii : A buried Roman city', 0.3)
#
#
# Recommended for: A. D. 62: Pompeii
# ('A. D. 62: Pompeii', 0.42)
# ('Household Gods', 0.38)
#
#
# Recommended for: I Was There: The Buried City of Pompeii (I Was There)
# ('Pompeii (Roman World)', 0.21)
# ('Pompeii...Buried Alive! (Step-Into-Reading, Step 4)', 0.21)
# ('Life in Ancient Rome', 0.21)
# ('In Search of Pompeii : A buried Roman city', 0.18)
# ('In Search of a Homeland : The Story of the Aeneid', 0.15)
#
#
# Recommended for: Roman Pompeii: Space and Society
# ('Pompeii: Public and Private Life (Revealing Antiquity)', 0.44)
# ('Roman Pompeii: Space and Society', 0.44)
# ('Roman Pompeii: Space and Society', 0.38)
# ('Roman Pompeii: Space and Society', 0.29)
# ('Empire of Pleasures: Luxury and Indulgence in the Roman World', 0.26)
# ('Roman Pompeii: Space and Society', 0.17)
#
#
# Recommended for: Buried Singapore: Michigan's imaginary Pompeii
#
#
# Recommended for: Houses and Monuments of Pompeii: The Works of Fausto and Felice Niccolini
# ('Ruins of Ancient Rome: The Drawings of French Architects Who Won the Prix De Rome 1786-1924', 0.45)
#
#
# Recommended for: Pompeii: The Day a City Died
# ('Pompeii: The Day a City Died', 0.56)
# ('In Search of Pompeii : A buried Roman city', 0.33)
# ('Classical Art: From Greece to Rome (Oxford History of Art)', 0.3)
# ('Pompeii: The Day a City Died', 0.2)

# %% [markdown]
# ## Summary
#
# Well done! In this lab, you effectively created a recommendation system for a real world dataset!
