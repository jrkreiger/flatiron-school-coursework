# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
# Import required packages
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time

# %%
# Create the soup
response = requests.get('https://www.residentadvisor.net/events/us/newyork')
soup = BeautifulSoup(response.content, 'html.parser')

# Preview the soup
# soup.prettify

# %%
# Get the div containing relevant info
event_listings = soup.find('div', id="event-listing")

# %%
# Get the event list items
entries = event_listings.findAll('li')

# %%
# Preview an event list item
entries[0]
# Out:
# <li><p class="eventDate date"><a href="/events.aspx?ai=8&amp;v=day&amp;mn=9&amp;yr=2019&amp;dy=13"><span>Fri, 13 Sep 2019 /</span></a></p></li>

# %%
# Practice extracting one date
a_date = entries[0].find('p', class_='eventDate date')
a_date.text.strip()
# Out:
# 'Fri, 13 Sep 2019 /'

# %%
# Loop through 'entries' to extract dates
dates = []
for entry in entries:
    date = entry.find('p', class_='eventDate date')
    if date:
        date = date.text.strip()
        dates.append(date)
    
dates
# Out:
# ['Fri, 13 Sep 2019 /',
#  'Sat, 14 Sep 2019 /',
#  'Sun, 15 Sep 2019 /',
#  'Mon, 16 Sep 2019 /',
#  'Tue, 17 Sep 2019 /',
#  'Wed, 18 Sep 2019 /',
#  'Thu, 19 Sep 2019 /']

# %%
# Loop through 'entries' to extract names and venues
names = []
venues = []
for entry in entries:
    event = entry.find('h1', class_='event-title')
    if event:
        info = event.text.split(' at ')
        name = info[0].strip()
        venue = info[1].strip()
        names.append(name)
        venues.append(venue)

# %%
# Loop through 'entries' to extract number of attendees
attendees = []
for entry in entries:
    try:
        num_attend = int(re.match("(\d*)", entry.find('p', class_='attending').text)[0])
        attendees.append(num_attend)
    except:
        num_attend = np.nan

# %%
# Gather the data into a list of lists
rows = []
for entry in entries:
    date = entry.find('p', class_='eventDate date')
    if date:
        date = date.text.strip()
    event = entry.find('h1', class_='event-title')
    if event:
        info = event.text.split(' at ')
        name = info[0].strip()
        venue = info[1].strip()
    try:
        num_attend = int(re.match("(\d*)", entry.find('p', class_='attending').text)[0])
        attendees.append(num_attend)
    except:
        num_attend = np.nan
    rows.append([date, name, venue, num_attend])

# %%
# Convert the list of lists to a DataFrame
df = pd.DataFrame(rows)
df.columns = ['Date', 'Event_name', 'Venue', 'Number_of_Attendees']
df.head()
# Out:
#                  Date                                         Event_name  \
# 0  Fri, 13 Sep 2019 /  Anything Goes: Filsonik, Athesun & Little New ...
# 1                None                 James Murphy b2b The Black Madonna
# 2                None  The Bunker with Wata Igarashi / Aleksi Perala ...
# 3                None                                         HARDER NYC
# 4                None                  Friday: Timmy Regisford All Night
#
#               Venue  Number_of_Attendees
# 0             1 Oak                  NaN
# 1  Knockdown Center                401.0
# 2          BASEMENT                270.0
# 3     3 Dollar Bill                118.0
# 4          Nowadays                106.0

# %%
# Define a function to extract event info to DataFrame
def scrape_events(events_page_url):
    response = requests.get(events_page_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    event_listings = soup.find('div', id="event-listing")
    entries = event_listings.findAll('li')
    rows = []
    for entry in entries:
        date = entry.find('p', class_='eventDate date')
        if date:
            date = date.text.strip()
            todays_date = date
        event = entry.find('h1', class_='event-title')
        if event:
            info = event.text.split(' at ')
            name = info[0].strip()
            venue = info[1].strip()
            try:
                num_attend = int(re.match("(\d*)", entry.find('p', class_='attending').text)[0])
            except:
                num_attend = np.nan
            rows.append([name, venue, todays_date, num_attend])
#         elif date:
#             todays_date = date.text
        else:
            continue
    df = pd.DataFrame(rows)
    df.columns = ['Event_name', 'Venue', 'Date', 'Number_of_Attendees']
    return df

# %%
# Test the function on a url
scrape_events('https://www.residentadvisor.net/events/us/newyork')
# Out:
#                                             Event_name  \
# 0                   James Murphy b2b The Black Madonna
# 1    The Bunker with Wata Igarashi / Aleksi Perala ...
# 2                                           HARDER NYC
# 3                    Friday: Timmy Regisford All Night
# 4    Justin Martin, Justin Strauss (Elsewhere Rooftop)
# 5    Golden Record x Blind Colors present Jan Krueg...
# 6               Love Medicine: Dramian, Concret, Kawas
# 7                              Jlin, K-Hand, Scraaatch
# 8    Wolf + Lamb, Lloyd Plus SPIRITUAL MENTAL PHYSICAL
# 9               Thugfucker, Alexander:Louis and A-Rock
# 10   Discotechnique: Late Nite Tuff Guy, Pontchartr...
# 11   17 Virgins & Butt Disco present: A Cheeky Deco...
# 12                                  A Tribe Called Red
# 13                          Dancehall Exhibition Party
# 14   Manhattan Hip Hop vs. Reggae Yacht Party Caban...
# 15   Lucky You with DJs Maseo and Sucio Smash Speci...
# 16   D'Noir AM Saturday Morning Rooftop Afterhours ...
# 17                            Sustain-Release Year Six
# 18                                                HVOB
# 19                      Let's Play House X Samo Nights
# 20               whiplash: Entro Senestre / Cienfuegos
# 21             Sassmouth, Punisher, Day Cart & Wig-Wam
# 22                                     Tommie Sunshine
# 23                                  Material 22: Loren
# 24                   Area 51: The Rave Before The Raid
# 25   All IN Tour with Jaytech, Judah & Kems NYC Boa...
# 26   Good Looks & Sermon present: Buku Esseks Crusi...
# 27   Truly Summer with Truly Co. DJs and Guest Jack...
# 28                                          Groundwire
# 29                                    Nyfw After Hours
# ..                                                 ...
# 100                  Super Tuff! Zapelini & M. Vaughan
# 101  Don't F*ck with Us, Don't F*ck Without Us: A H...
# 102                                  Two Step Tuesdays
# 103                                  Cut-line Showcase
# 104                Feel Real presents Express Yourself
# 105                                             Cipher
# 106  Legends of Vinyl 2019 New York DJ/Artists Hall...
# 107                                     Catching Flies
# 108       Bateria with DJ Bruce, Toribio, Mickey Perez
# 109                        Popgun presents: Nitzer Ebb
# 110                              Open Decks Session 81
# 111                                         So•natural
# 112  Technosupportgroup: Relaxer, Moment Trigger, H...
# 113                                       Susan Alcorn
# 114  Luke Vibert, DJ Warp Plus Ant Larock, Pablo Ro...
# 115                           Melting Point: Melania .
# 116                           Wave Sessions with Compa
# 117                                        Grace Kelly
# 118                Nakam with The Duchess & Megatronic
# 119  Seemingly Normal People with Nu Sky, Moon + A....
# 120   Full Flex: Side Hustle with Jossy Mitsu & Ma Sha
# 121  Dog Rescue Fundraiser with Heathered Pearls & ...
# 108                   Good Room  Wed, 18 Sep 2019 /                  4.0
# 109                      Warsaw  Wed, 18 Sep 2019 /                  4.0
# 110                        Eris  Wed, 18 Sep 2019 /                  2.0
# 111                TBA Brooklyn  Wed, 18 Sep 2019 /                  NaN
# 112       Bossa Nova Civic Club  Wed, 18 Sep 2019 /                  NaN
# 113         James Cohan Gallery  Wed, 18 Sep 2019 /                  NaN
# 114                   Good Room  Thu, 19 Sep 2019 /                 24.0
# 115  Secret Location - Brooklyn  Thu, 19 Sep 2019 /                 11.0
# 116              The Brown Note  Thu, 19 Sep 2019 /                  7.0
# 117            Le Poisson Rouge  Thu, 19 Sep 2019 /                  1.0
# 118                     Le Bain  Thu, 19 Sep 2019 /                  4.0
# 119                TBA Brooklyn  Thu, 19 Sep 2019 /                  4.0
# 120                   Rose Gold  Thu, 19 Sep 2019 /                  NaN
# 121              public records  Thu, 19 Sep 2019 /                  NaN
# 122                House Of Yes  Thu, 19 Sep 2019 /                  NaN
# 123                   Elsewhere  Thu, 19 Sep 2019 /                  NaN
# 124                   Mood Ring  Thu, 19 Sep 2019 /                  NaN
# 125          10 Corso Como, NYC  Thu, 19 Sep 2019 /                  NaN
# 126                    MoMA PS1  Thu, 19 Sep 2019 /                  NaN
# 127             The Sultan Room  Thu, 19 Sep 2019 /                  NaN
# 128                 Synesthesia  Thu, 19 Sep 2019 /                  NaN
# 129                       1 Oak  Thu, 19 Sep 2019 /                  NaN
#
# [130 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
# Find the next button in the html
next_button = soup.find('li', id='liNext')
next_button
# Out:
# <li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/us/newyork/week/2019-09-20">Next </a>
# </li>

# %%
# Extract the slug for the next page's url
next_slug = next_button.find('a').attrs['href']
next_slug
# Out:
# '/events/us/newyork/week/2019-09-20'

# %%
# Split the original url so new slug can be attached
url = 'https://www.residentadvisor.net/events/us/newyork'
url_stem = url.split('/events')[0]
url_stem
# Out:
# 'https://www.residentadvisor.net'

# %%
# Concatenate new url from stem and slug
next_url = url_stem + next_slug
next_url
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2019-09-20'

# %%
# Define a function to get the next page's url given a url
def next_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
#     next_button = soup.find('li', id='liNext')
#     next_slug = next_button.find('a').attrs['href']
    url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
#     url_stem = url.split('/events')[0]
#     next_url = url_stem + next_slug
    next_page_url = "https://www.residentadvisor.net" + url_ext
    return next_url

# %%
# Test the function on a url
next_page('https://www.residentadvisor.net/events/us/newyork')
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2019-09-20'

# %%
# Test the function on another url
next_page('https://www.residentadvisor.net/events/us/newyork/week/2019-09-20')
# Out:
# 'https://www.residentadvisor.net/events/us/newyork/week/2019-09-27'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
test_scrape = scrape_events('https://www.residentadvisor.net/events/us/newyork')
len(test_scrape)
# Out:
# 130

# %%
# # Solution
# dfs = []
# total_rows = 0
# cur_url = "https://www.residentadvisor.net/events/us/newyork"
# while total_rows <= 1000:
#     df = scrape_events(cur_url)
#     dfs.append(df)
#     total_rows += len(df)
#     cur_url = next_page(cur_url)
#     time.sleep(.2)
# df = pd.concat(dfs)
# df = df.iloc[:1000]
# print(len(df))
# df.head()
# Out:
# 1000
#                                           Event_name             Venue  \
# 0                 James Murphy b2b The Black Madonna  Knockdown Center
# 1  The Bunker with Wata Igarashi / Aleksi Perala ...          BASEMENT
# 2                                         HARDER NYC     3 Dollar Bill
# 3                  Friday: Timmy Regisford All Night          Nowadays
# 4  Justin Martin, Justin Strauss (Elsewhere Rooftop)         Elsewhere
#
#                  Date  Number_of_Attendees
# 0  Fri, 13 Sep 2019 /                403.0
# 1  Fri, 13 Sep 2019 /                270.0
# 2  Fri, 13 Sep 2019 /                122.0
# 3  Fri, 13 Sep 2019 /                107.0
# 4  Fri, 13 Sep 2019 /                 94.0

# %%
# My attempt
dfs_list = []
total_length = 0
current_url = "https://www.residentadvisor.net/events/us/newyork"
while total_length <= 1000:
    new_df = scrape_events(current_url)
    dfs_list.append(new_df)
    total_length += len(new_df)
    current_url = next_page(current_url)
    time.sleep(1)
master_df = pd.concat(dfs_list)
master_df = master_df.iloc[:1000]
print(len(master_df))
master_df.head()
# Out:
# 1000
#                                           Event_name             Venue  \
# 0                 James Murphy b2b The Black Madonna  Knockdown Center
# 1  The Bunker with Wata Igarashi / Aleksi Perala ...          BASEMENT
# 2                                         HARDER NYC     3 Dollar Bill
# 3                  Friday: Timmy Regisford All Night          Nowadays
# 4  Justin Martin, Justin Strauss (Elsewhere Rooftop)         Elsewhere
#
#                  Date  Number_of_Attendees
# 0  Fri, 13 Sep 2019 /                403.0
# 1  Fri, 13 Sep 2019 /                270.0
# 2  Fri, 13 Sep 2019 /                122.0
# 3  Fri, 13 Sep 2019 /                107.0
# 4  Fri, 13 Sep 2019 /                 94.0

# %%
master_df.sort_values('Number_of_Attendees', ascending=False)
# Out:
#                                            Event_name  \
# 78            All Day I Dream's Summer Season Closing
# 24            Paradise New York: Jamie Jones, Masters
# 24            Paradise New York: Jamie Jones, Masters
# 24            Paradise New York: Jamie Jones, Masters
# 24            Paradise New York: Jamie Jones, Masters
# 24            Paradise New York: Jamie Jones, Masters
# 24            Paradise New York: Jamie Jones, Masters
# 24            Paradise New York: Jamie Jones, Masters
# 24            Paradise New York: Jamie Jones, Masters
# 24            Paradise New York: Jamie Jones, Masters
# 0                  James Murphy b2b The Black Madonna
# 37                   Zero presents... The Golden Boat
# 79                   Zero presents... The Golden Boat
# 1   The Bunker with Wata Igarashi / Aleksi Perala ...
# 0                       Ellen Allien / Volvox / Juana
# 0                       Ellen Allien / Volvox / Juana
# 0                       Ellen Allien / Volvox / Juana
# 0                       Ellen Allien / Volvox / Juana
# 0                       Ellen Allien / Volvox / Juana
# 0                       Ellen Allien / Volvox / Juana
# 0                       Ellen Allien / Volvox / Juana
# 0                       Ellen Allien / Volvox / Juana
# 0                       Ellen Allien / Volvox / Juana
